# %% [markdown]
# # Tutorial: Quick start
# Author info: Jiaqi Cai@Department of Physics, University of Washington, Seattle, WA 98195, email address caidish[at]uw.edu.
#
# This tutorial shows how to use this package to do all the data acqusition from:
# - Sweep0D: monitor all the *follow_params* followed parameters as a function of system time.
# - Sweep1D: monitor all the followed parameters when sweeping one paramter. This sweep1D can do sweep one-way or back-and-forth, or continously.
# - Sweep2D: monitor all the followed parameters when sweeping two paramters in a back-and-forth scan. The inner parameter will be swept back and forth and outer parameter will step when one loop finished.
# - SimuSweep: same as sweep1D, but two parameters could be scanned simutaneously.
# - SweepQueue: consist of the queue of sweep0D, sweep1D, sweep2D and SimuSweep and any user defined function. The sweeps will be run one by one.
#
# I will use the MockParabola function from qcodes' test instrument. The simulated device Mockparabola has main parameters *parabola*, *x*,*y*,*z* and *noise*. The output parabola is a quadric function of x,y,z in the presence of noise.

# %% [markdown]
# ## Import essential modules

# %%
import qcodes as qc
from qcodes.instrument_drivers.mock_instruments import MockParabola

from measureit import (
    Sweep0D,
    Sweep1D,
    Sweep2D,
    SimulSweep,
    get_path,
    GateLeakage,
    get_data_dir,
)
from measureit.tools import ensure_qt, init_database

ensure_qt()
# Set MEASUREIT_FORCE_QT=1 to bypass the probe once Qt is configured.
from measureit.tools.sweep_queue import SweepQueue, DatabaseEntry

# %%
# where the data will be saved
print(f"Data directory: {get_data_dir()}")
print(f"Database directory: {get_path('databases')}")
# Out:
# Data directory: /Users/caijiaqi/Documents/GitHub/MeasureIt
# Database directory: /Users/caijiaqi/Documents/GitHub/MeasureIt/Databases

# %% [markdown]
# ## Define the instrument(s)
#
# We imported a test instrument 'MockParabola' from qcodes' tests. Other supported drivers could be found in [qcodes driver list](https://github.com/QCoDeS/Qcodes/tree/master/qcodes/instrument_drivers) and [contributed driver list](https://github.com/QCoDeS/Qcodes_contrib_drivers/tree/master/qcodes_contrib_drivers/drivers). We also have some user contributed driver (e.g. old lakeshore)

# %%
instr0 = MockParabola(name="test_instrument0")
instr0.noise.set(3)
instr0.parabola.label = "Value of instr0"
instr1 = MockParabola(name="test_instrument1")
instr1.noise.set(10)
instr1.parabola.label = "Value of instr1"
# Out:
# /Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/websockets/legacy/__init__.py:6: DeprecationWarning: websockets.legacy is deprecated; see https://websockets.readthedocs.io/en/stable/howto/upgrade.html for upgrade instructions
#   warnings.warn(  # deprecated in 14.0 - 2024-11-09
# /Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/uvicorn/protocols/websockets/websockets_impl.py:17: DeprecationWarning: websockets.server.WebSocketServerProtocol is deprecated
#   from websockets.server import WebSocketServerProtocol
# INFO:     Started server process [96970]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8123 (Press CTRL+C to quit)
# INFO:     127.0.0.1:50170 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50170 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:50170 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50175 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     Shutting down
# INFO:     Waiting for connections to close. (CTRL+C to force quit)
# ERROR:    Exception in ASGI application
# Traceback (most recent call last):
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/uvicorn/protocols/http/h11_impl.py", line 403, in run_asgi
#     result = await app(  # type: ignore[func-returns-value]
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/uvicorn/middleware/proxy_headers.py", line 60, in __call__
#     return await self.app(scope, receive, send)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/applications.py", line 107, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/middleware/errors.py", line 164, in __call__
#     await self.app(scope, receive, _send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/fastmcp/server/http.py", line 97, in __call__
#     await self.app(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/middleware/exceptions.py", line 63, in __call__
#     await wrap_app_handling_exceptions(self.app, conn)(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/_exception_handler.py", line 42, in wrapped_app
#     await app(scope, receive, sender)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/routing.py", line 716, in __call__
#     await self.middleware_stack(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/routing.py", line 736, in app
#     await route.handle(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/routing.py", line 290, in handle
#     await self.app(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/fastmcp/server/http.py", line 41, in __call__
#     await self.session_manager.handle_request(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/mcp/server/streamable_http_manager.py", line 149, in handle_request
#     await self._handle_stateful_request(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/mcp/server/streamable_http_manager.py", line 221, in _handle_stateful_request
#     await transport.handle_request(scope, receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/mcp/server/streamable_http.py", line 399, in handle_request
#     await self._handle_get_request(request, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/mcp/server/streamable_http.py", line 742, in _handle_get_request
#     await response(request.scope, request.receive, send)
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/sse_starlette/sse.py", line 255, in __call__
#     async with anyio.create_task_group() as task_group:
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 787, in __aexit__
#     raise exc_val
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/anyio/_backends/_asyncio.py", line 755, in __aexit__
#     await self._on_completed_fut
# asyncio.exceptions.CancelledError
# ERROR:    Traceback (most recent call last):
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/starlette/routing.py", line 701, in lifespan
#     await receive()
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/site-packages/uvicorn/lifespan/on.py", line 137, in receive
#     return await self.receive_queue.get()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/caijiaqi/miniforge3/envs/instrMCPdev/lib/python3.11/asyncio/queues.py", line 158, in get
#     await getter
# asyncio.exceptions.CancelledError

# %% [markdown]
# What we do is to create two instances of MockParabola. In other cases when people need to deal with multiple instruments, they can be imported and defined one by one. For parameters, the 'label' property will appear as the y-axis name when we dynamically display the measurement result.

# %% [markdown]
# ## Sweep 0d to monitor the noise

# %%
s = Sweep0D(
    inter_delay=0.1, save_data=True, plot_bin=4, max_time=100
)  # inter_delay is the delay after qcodes collecting all data. inter_delay = 0.05 corresponds to a maximum sampling rate @200S/s.
follow_params = {  # Define which parameters you want to follow (plot and/or save)
    instr0.parabola,
    instr1.parabola,
}
s.follow_param(*follow_params)
# Out:
# 2026-01-26 00:54:06,112 | measureit.sweeps.Sweep0D | INFO | time sweep: step size 0.1 s, points 1000.

# %% [markdown]
# The 0d sweep which monitors the output will last for max_time (in unit of seconds), which now is set as 100s.

# %%
try:
    # Make sure database_name and the path are set to the correct values!
    database_name = "Test_database.db"
    exp_name = "testsweep"
    sample_name = "test0d"
    init_database(database_name, exp_name, sample_name, s)
except:
    print("Error opening database")

# %%
print(s)

# %%
s.start()

# %%
ds = qc.dataset.load_by_id(1)

# %%
ds.metadata

# %% [markdown]
# Before the max_time reaches, one way to stop is to use ESC on your keyboard. Another way to stop it is run the code below. **Note that closing the plotter's window doesn't neccessarity stops the data acquisition.**

# %%
s.progressState.state

# %%
s.kill()

# %% [markdown]
# When the sweep is running on the background, however, although the data is acquired in another process, the plotting is still requiring CPU time from this notebook's thread. time.sleep() will pause the plotting but preassumely not the data acquisition.

# %% [markdown]
# ## Sweep 1d
# The sweep 1d function takes one parameter import, which is instr0's x parameter.
# It also requires a start point, end point, rate. **If the parameter is not at 'start', it will safely sweep to 'start' with the rate, making sure there is no jump in any physical instrument.**

# %%
start = 0
end = 10
rate = 0.02
s = Sweep1D(
    instr0.x,
    start,
    end,
    rate,
    inter_delay=0.05,
    save_data=True,
    bidirectional=True,
    plot_bin=4,
    continual=False,
)
follow_params = {  # Define which parameters you want to follow (plot and/or save)
    instr0.parabola,
    instr1.parabola,
}
s.follow_param(*follow_params)

# %%
s._params[1]

# %%
try:
    # Make sure database_name and the path are set to the correct values!
    database_name = "Test_database.db"
    exp_name = "testsweep"
    sample_name = "test1d"
    init_database(database_name, exp_name, sample_name, s)
except:
    print("Error opening database")

# %%
print(s)

# %%
ensure_qt()
s.start()

# %% [markdown]
# During the scan, like sweep0d, there are multiple ways to stop it. Besides, the 'spacebar' could revert the scanning axis.

# %%
s.kill()

# %% [markdown]
# ## Limit test
# This limit test will sweep back automatically once a limit is triggered, which can be used for gate limit test.

# %%
gl = GateLeakage(
    instr0.x,
    instr0.parabola,
    max_I=10,
    limit=20,
    step=0.1,
    inter_delay=0.2,
    save_data=False,
)

# %%
ensure_qt()
gl.start()

# %%
gl.kill()

# %% [markdown]
# ## Simulsweep
# The simulsweep function mimics sweep 1D but take two different parameter. The step must be set correctly that the total steps for each parameters are equal.

# %%
parameter_dict_forward = {
    instr0.x: {"start": 0, "stop": 5, "step": 0.02},
    instr1.x: {"start": 0, "stop": 10, "step": 0.04},
}
sweep_args = {
    "bidirectional": True,
    "plot_bin": 4,
    "continual": False,
    "save_data": True,
    "inter_delay": 0.05,
}
s = SimulSweep(parameter_dict_forward, **sweep_args)  # Likely want to save this sweep
follow_params = {  # Define which parameters you want to follow (plot and/or save)
    instr0.parabola,
    instr1.parabola,
}
s.follow_param(*follow_params)

# %%
try:
    # Make sure database_name and the path are set to the correct values!
    database_name = "Test_database.db"
    exp_name = "testsweep"
    sample_name = "testSimu"
    init_database(database_name, exp_name, sample_name, s)
except:
    print("Error opening database")

# %%
ensure_qt()
s.start()

# %%
s.progressState.state

# %%
s.kill()

# %% [markdown]
# ## Sweep Queue
# The most important application of this code is that you can freely stack all sweep types and user defined function together. Here I will show a sweepqueue that:
# - sweep instr0's x from 0 to 5
# - print a dummy string 1
# - sweep instr1's x and y from 0 to 5
# - print a dummy string 2

# %%
def dummystring(index):
    if index == 1:
        print("Lorem ipsum dolor sit amet, consectetur adipiscing elit.")
    elif index == 2:
        print(
            "Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat."
        )

# %%
sq = SweepQueue()
follow_params = {  # Define which parameters you want to follow (plot and/or save)
    instr0.parabola,
    instr1.parabola,
}

# %% [markdown]
# SweepQueue accept sweep object and associated database if save_data is set to be True.
#
# The += operator is overload for SweepQueue, so that the sweep,databaseentry tuple pair can be directly added into it. Same thing as the append function

# %%
# set up the sweep
start = 0
end = 5
rate = 0.2
s1 = Sweep1D(
    instr0.x,
    start,
    end,
    rate,
    inter_delay=0.2,
    save_data=True,
    bidirectional=True,
    plot_bin=4,
    continual=False,
)
s1.follow_param(*follow_params)

db_name = "Test_database.db"
db_path = str(get_path("databases") / db_name)
exp_name = "testsweepqueue"
sample_name = "test1d"

# set up the database
db_entry = DatabaseEntry(db_path, exp_name, sample_name)
sq += (db_entry, s1)
# Out:
# 2026-01-26 01:10:03,637 | measureit.sweeps.Sweep1D | INFO | x sweep: step size 0.2 a.u., steps 25, points 26.

# %%
# add dummy string print
sq += (dummystring, 1)

# %%
# set up the sweep
parameter_dict_forward = {
    instr0.x: {"start": 0, "stop": 5, "step": 0.02},
    instr0.y: {"start": 0, "stop": 5, "step": 0.02},
}
sweep_args = {
    "bidirectional": True,
    "plot_bin": 4,
    "continual": False,
    "save_data": True,
    "inter_delay": 0.1,
}
s2 = SimulSweep(parameter_dict_forward, **sweep_args)  # Likely want to save this sweep
s2.follow_param(*follow_params)
db_name = "Test_database.db"
db_path = str(get_path("databases") / db_name)
exp_name = "testsweepqueue"
sample_name = "testsimulsweep"

# set up the database
db_entry = DatabaseEntry(db_path, exp_name, sample_name)
sq += (db_entry, s2)
# Out:
# 2026-01-26 01:10:04,132 | measureit.sweeps.SimulSweep | INFO | x sweep: step size 0.02 a.u., steps 250, points 251.
# 2026-01-26 01:10:04,134 | measureit.sweeps.SimulSweep | INFO | y sweep: step size 0.02 a.u., steps 250, points 251.

# %%
# add dummy string print
sq += (dummystring, 2)

# %% [markdown]
# The SweepQueue is iterable, so you can iterate it and print every one's name

# %%
for n, s in enumerate(sq):
    print(str(n) + ". " + str(s))
# Out:
# 0. Database entry: /Users/caijiaqi/Documents/GitHub/MeasureIt/Databases/Test_database.db | Experiment: testsweepqueue | Sample: test1d
# 1. 1D Sweep of x from 0 to 5, with step size 0.2.
# 2. functools.partial(<function dummystring at 0x167c63880>, 1)
# 3. Database entry: /Users/caijiaqi/Documents/GitHub/MeasureIt/Databases/Test_database.db | Experiment: testsweepqueue | Sample: testsimulsweep
# 4. SimulSweep of x from 0 to 5, with step 0.02, and y from 0 to 5, with step 0.02.
# 5. functools.partial(<function dummystring at 0x167c63880>, 2)

# %%
ensure_qt()
sq.start()
# Out:
# 2026-01-26 01:10:07,385 | measureit.sweeps.queue | INFO | Starting sweeps
# There is (are) already experiment(s) with the name of testsweepqueue and sample name of test1d in the database.
# 2026-01-26 01:10:07,402 | measureit.sweeps.queue | INFO | Starting sweep of x from 0 (a.u.) to 5 (a.u.)
# 2026-01-26 01:10:08,404 | measureit.sweeps.Sweep1D | INFO | Ramping to our starting setpoint value of 0 (a.u.)
# 2026-01-26 01:10:08,405 | measureit.sweeps.Sweep1D | INFO | Done ramping x to 0 (a.u.)
# 2026-01-26 01:10:08,406 | measureit.sweeps.Sweep1D | INFO | Sweeping x to 5 (a.u.)
# INFO:     Started server process [96970]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8123 (Press CTRL+C to quit)
# INFO:     127.0.0.1:50213 - "POST /mcp HTTP/1.1" 400 Bad Request
# INFO:     127.0.0.1:50213 - "POST /mcp HTTP/1.1" 400 Bad Request
# INFO:     127.0.0.1:50218 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50218 - "POST /mcp HTTP/1.1" 202 Accepted
# INFO:     127.0.0.1:50218 - "GET /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50221 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50227 - "POST /mcp HTTP/1.1" 200 OK
# INFO:     127.0.0.1:50227 - "POST /mcp HTTP/1.1" 200 OK

# %%
sq.status()
# Out:
# {'effective_state': 'running',
#  'current_sweep_state': None,
#  'queue_length': 3,
#  'current_sweep_type': None,
#  'current_action_type': 'callable',
#  'last_error': None}

# %%
sq.kill_all()

# %% [markdown]
# ## Sweep 2D
# The 2D sweep, which is sweeping one parameter back and forth and then step one of the parameter, could be easily achieved by using sweep queue.
# Sweep2d is a good substitute of sweepqueue (though many users still use sweepqueue for 2D sweep) if you only want to take a 2d map in a single file. Here we will sweep Mockparabola's x and y to generate a 2d map.

# %%
# define 2d map
outer_para = instr0.y
outer_dv = 0.5
outer_start = -2.5
outer_end = 2.5

inner_para = instr0.x
inner_dv = 0.1
inner_start = -2.5
inner_end = 2.5

multiplier = 4
inter_delay = 0.1
outer_delay = 1
s = Sweep2D(
    [inner_para, inner_start, inner_end, inner_dv],
    [outer_para, outer_start, outer_end, outer_dv],
    inter_delay=inter_delay,
    outer_delay=outer_delay,
    save_data=True,
    plot_data=True,
    complete_func=None,
    update_func=None,
    plot_bin=5,
    back_multiplier=multiplier,
    out_ministeps=1,
)
follow_params = {  # Define which parameters you want to follow (plot and/or save)
    instr0.parabola,
    instr1.parabola,
}
s.follow_param(*follow_params)
print(s)

# %%
# define the parameter to follow by the heatmap
s.follow_heatmap_param([instr0.parabola, instr1.parabola])

# %%
print(s)

# %%
try:
    # Make sure database_name and the path are set to the correct values!
    database_name = "Test_database.db"
    exp_name = "testsweep"
    sample_name = "test2d"
    init_database(database_name, exp_name, sample_name, s)
except:
    print("Error opening database")

# %%
ensure_qt()
s.start()

# %%
s.progressState.state

# %%
s.kill()
